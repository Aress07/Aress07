# %%
#Fonction de hashage
import random
def BuildHashMap(c):
    keys = list(range(c))
    HashMa = {key: [] for key in keys}
    return HashMa

def _Hash(num,HashMap,c=10): 
    for i in num:  
        n = i % c
        HashMap[n].append(i)  

def Trying():
    m = [100, 1000, 10000, 100000]
    for j in m:
        HashMap = BuildHashMap(10)
        n = 2 * j
        res = [random.randrange(1, 10000, 1) for i in range(n)]
        _Hash(res,HashMap)
        print(HashMap)

Trying()
# Out:
# {0: [3400, 590, 8010, 3470, 740, 4520, 3990, 3990, 2570, 680, 370], 1: [7591, 71, 1381, 6121, 9771, 5801, 1051, 3691, 2091, 6171, 2291, 6401, 9911, 6691, 161, 1181, 8031, 2401, 8031], 2: [2992, 5872, 1352, 4132, 4762, 8702, 5412, 4672, 132, 9972, 7792, 762, 2512, 3872, 3322, 8382, 8632, 1102, 2752, 4012, 7472, 4012, 4572], 3: [5103, 7153, 5003, 9583, 4193, 3373, 1053, 883, 3533, 8673, 3173, 9793, 653, 6783, 9973, 1113, 5763, 6863, 383, 5863, 1073, 2913, 3823, 6253, 8543], 4: [5644, 8024, 4674, 5184, 484, 294, 8954, 564, 5274, 5924, 4374, 6754, 2314, 6224, 2774, 4384, 8554, 8054, 7124], 5: [7355, 7455, 1895, 1205, 1735, 835, 795, 5285, 8435, 3585, 2595, 6305, 6385, 4845, 9725, 1195, 9525, 9685, 1135, 15, 195], 6: [916, 9236, 7386, 5576, 5356, 8506, 886, 4616, 8666, 2676, 7206, 7046, 6486, 306, 6936, 5236, 5296], 7: [9027, 6907, 5647, 7027, 1757, 9287, 5897, 4057, 1057, 2527, 7417, 5577, 2427, 5137, 9107, 7327, 1187, 327, 6107, 4587, 1627], 8: [128, 9878, 5808, 9048, 8808, 8638, 1208, 
# ...

# %%
def hashage(c,i=0,a=1,hashmap=None):
    if hashmap is None:
        hashmap = {}
    m = 11
    h = ((c % 11) + i*a)%11
    if h not in hashmap:
        hashmap[h] = c
    else:
        return hashage(c,i+1,a,hashmap)
    return hashmap
